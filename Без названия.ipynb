# %%
import pandas as pd

# %%
pa = '.data/MSK-Big - Rooms.csv'
df = pd.read_csv(pa)
df.head()
# Out:
#       Name     Slug             Collection ID                   Item ID  \
# 0   room-1   room-1  628debfda8ef95588c986c04  628dee39f71c22686282d516
# 1  room-10  room-10  628debfda8ef95588c986c04  628dee401b0f4f35bd0e70f7
# 2  room-11  room-11  628debfda8ef95588c986c04  628dee4045bef812e5b344ec
# 3  room-12  room-12  628debfda8ef95588c986c04  628dee412ef8ea7ac9f7961e
# 4  room-13  room-13  628debfda8ef95588c986c04  628dee4235672177c90e5ee9
#
#                                           Created On  \
# 0  Wed May 25 2022 08:52:09 GMT+0000 (Coordinated...
# 1  Wed May 25 2022 08:52:16 GMT+0000 (Coordinated...
# 2  Wed May 25 2022 08:52:16 GMT+0000 (Coordinated...
# 3  Wed May 25 2022 08:52:17 GMT+0000 (Coordinated...
# 4  Wed May 25 2022 08:52:18 GMT+0000 (Coordinated...
#
#                                           Updated On  \
# 0  Thu May 26 2022 22:38:44 GMT+0000 (Coordinated...
# 1  Wed Sep 07 2022 19:17:14 GMT+0000 (Coordinated...
# ...

# %%
list(enumerate(df.columns))
# Out:
# [(0, 'Name'),
#  (1, 'Slug'),
#  (2, 'Collection ID'),
#  (3, 'Item ID'),
#  (4, 'Created On'),
#  (5, 'Updated On'),
#  (6, 'Published On'),
#  (7, 'Заголовок'),
#  (8, 'Цена'),
#  (9, 'price_per_meter'),
#  (10, 'Район'),
#  (11, 'map'),
#  (12, 'Адрес'),
#  (13, 'Image'),
#  (14, 'Images'),
#  (15, 'Описание'),
#  (16, 'Contact'),
#  (17, 'Валюта'),
#  (18, 'Общая площадь'),
#  (19, 'Комнат'),
#  (20, 'Этаж'),
#  (21, 'Всего этажей'),
#  (22, 'Ремонт'),
#  (23, 'Год постройки'),
#  (24, 'Тип (материал) дома'),
#  (25, 'Раздельные санузлы'),
#  (26, 'Высота потолков'),
#  (27, 'Пассажирских лифтов'),
#  (28, 'Грузовых лифтов'),
#  (29, 'Парковка'),
#  (30, 'Форма собственности'),
#  (31, 'Кол во подъездов'),
#  (32, 'Квартир на этаже'),
#  (33, 'Пентхаус'),
#  (34, 'Терраса'),
#  (35, 'Квартир в доме'),
#  (36, 'Окна выходят')]

# %%
df['area']
